# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as scs
# %matplotlib inline

# %%
data = pd.read_csv("~/staticGreeenBook/midoribon/Chap3/data3a.csv")

# %%
data
# Out:
#      y      x  f
# 0    6   8.31  C
# 1    6   9.44  C
# 2    6   9.50  C
# 3   12   9.07  C
# 4   10  10.16  C
# 5    4   8.32  C
# 6    9  10.61  C
# 7    9  10.06  C
# 8    9   9.93  C
# 9   11  10.43  C
# 10   6  10.36  C
# 11  10  10.15  C
# 12   6  10.92  C
# 13  10   8.85  C
# 14  11   9.42  C
# 15   8  11.11  C
# 16   3   8.02  C
# 17   8  11.93  C
# 18   5   8.55  C
# 19   5   7.19  C
# 20   4   9.83  C
# 21  11  10.79  C
# 22   5   8.89  C
# 23  10  10.09  C
# 24   6  11.63  C
# 25   6  10.21  C
# 26   7   9.45  C
# 27   9  10.44  C
# 28   3   9.44  C
# 29  10  10.48  C
# ..  ..    ... ..
# 70  10  10.54  T
# 71   8  11.30  T
# 72   8  12.40  T
# 73   7  10.18  T
# 74   5   9.53  T
# 75   6  10.24  T
# 76   8  11.76  T
# 77   9   9.52  T
# 78   9  10.40  T
# 79   6   9.96  T
# 80   7  10.30  T
# 81  10  11.54  T
# 82   6   9.42  T
# 83  11  11.28  T
# 84  11   9.73  T
# 85  11  10.78  T
# 86   5  10.21  T
# 87   6  10.51  T
# 88   4  10.73  T
# 89   5   8.85  T
# 90   6  11.20  T
# 91   5   9.86  T
# 92   8  11.54  T
# 93   5  10.03  T
# 94   9  11.88  T
# 95   8   9.15  T
# 96   6   8.52  T
# 97   8  10.24  T
# 98   7  10.86  T
# 99   9   9.97  T
#
# [100 rows x 3 columns]

# %%
data.shape
# Out:
# (100, 3)

# %%
data.x
# Out:
# 0      8.31
# 1      9.44
# 2      9.50
# 3      9.07
# 4     10.16
# 5      8.32
# 6     10.61
# 7     10.06
# 8      9.93
# 9     10.43
# 10    10.36
# 11    10.15
# 12    10.92
# 13     8.85
# 14     9.42
# 15    11.11
# 16     8.02
# 17    11.93
# 18     8.55
# 19     7.19
# 20     9.83
# 21    10.79
# 22     8.89
# 23    10.09
# 24    11.63
# 25    10.21
# 26     9.45
# 27    10.44
# 28     9.44
# 29    10.48
#       ...
# 70    10.54
# 71    11.30
# 72    12.40
# 73    10.18
# 74     9.53
# 75    10.24
# 76    11.76
# 77     9.52
# 78    10.40
# 79     9.96
# 80    10.30
# 81    11.54
# 82     9.42
# 83    11.28
# 84     9.73
# 85    10.78
# 86    10.21
# 87    10.51
# 88    10.73
# 89     8.85
# 90    11.20
# 91     9.86
# 92    11.54
# 93    10.03
# 94    11.88
# 95     9.15
# 96     8.52
# 97    10.24
# 98    10.86
# 99     9.97
# Name: x, Length: 100, dtype: float64

# %%
data.f
# Out:
# 0     C
# 1     C
# 2     C
# 3     C
# 4     C
# 5     C
# 6     C
# 7     C
# 8     C
# 9     C
# 10    C
# 11    C
# 12    C
# 13    C
# 14    C
# 15    C
# 16    C
# 17    C
# 18    C
# 19    C
# 20    C
# 21    C
# 22    C
# 23    C
# 24    C
# 25    C
# 26    C
# 27    C
# 28    C
# 29    C
#      ..
# 70    T
# 71    T
# 72    T
# 73    T
# 74    T
# 75    T
# 76    T
# 77    T
# 78    T
# 79    T
# 80    T
# 81    T
# 82    T
# 83    T
# 84    T
# 85    T
# 86    T
# 87    T
# 88    T
# 89    T
# 90    T
# 91    T
# 92    T
# 93    T
# 94    T
# 95    T
# 96    T
# 97    T
# 98    T
# 99    T
# Name: f, Length: 100, dtype: object

# %%
data.f.dtype
# Out:
# dtype('O')

# %%
data.describe()
# Out:
#                 y           x
# count  100.000000  100.000000
# mean     7.830000   10.089100
# std      2.624881    1.008049
# min      2.000000    7.190000
# 25%      6.000000    9.427500
# 50%      8.000000   10.155000
# 75%     10.000000   10.685000
# max     15.000000   12.400000

# %%
data.f[data.f=="C"] = "0"
data.f[data.f=="T"] = "1"
# Out:
# /home/yutaka/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/yutaka/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data
# Out:
#      y      x  f
# 0    6   8.31  0
# 1    6   9.44  0
# 2    6   9.50  0
# 3   12   9.07  0
# 4   10  10.16  0
# 5    4   8.32  0
# 6    9  10.61  0
# 7    9  10.06  0
# 8    9   9.93  0
# 9   11  10.43  0
# 10   6  10.36  0
# 11  10  10.15  0
# 12   6  10.92  0
# 13  10   8.85  0
# 14  11   9.42  0
# 15   8  11.11  0
# 16   3   8.02  0
# 17   8  11.93  0
# 18   5   8.55  0
# 19   5   7.19  0
# 20   4   9.83  0
# 21  11  10.79  0
# 22   5   8.89  0
# 23  10  10.09  0
# 24   6  11.63  0
# 25   6  10.21  0
# 26   7   9.45  0
# 27   9  10.44  0
# 28   3   9.44  0
# 29  10  10.48  0
# ..  ..    ... ..
# 70  10  10.54  1
# 71   8  11.30  1
# 72   8  12.40  1
# 73   7  10.18  1
# 74   5   9.53  1
# 75   6  10.24  1
# 76   8  11.76  1
# 77   9   9.52  1
# 78   9  10.40  1
# 79   6   9.96  1
# 80   7  10.30  1
# 81  10  11.54  1
# 82   6   9.42  1
# 83  11  11.28  1
# 84  11   9.73  1
# 85  11  10.78  1
# 86   5  10.21  1
# 87   6  10.51  1
# 88   4  10.73  1
# 89   5   8.85  1
# 90   6  11.20  1
# 91   5   9.86  1
# 92   8  11.54  1
# 93   5  10.03  1
# 94   9  11.88  1
# 95   8   9.15  1
# 96   6   8.52  1
# 97   8  10.24  1
# 98   7  10.86  1
# 99   9   9.97  1
#
# [100 rows x 3 columns]

# %%
plt.scatter(data.x, data.y, c=data.f, label=("0","1"))

# %%
data.boxplot(column='y', by='f')

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
model = smf.glm('y ~ x', data = data, family = sm.families.Poisson())
# Out:
# /home/yutaka/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
result = model.fit()

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  100
# Model:                            GLM   Df Residuals:                       98
# Model Family:                 Poisson   Df Model:                            1
# Link Function:                    log   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -235.39
# Date:                Sun, 18 Mar 2018   Deviance:                       84.993
# Time:                        12:28:00   Pearson chi2:                     83.8
# No. Iterations:                     4
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.2917      0.364      3.552      0.000       0.579       2.005
# x              0.0757      0.036      2.125      0.034       0.006       0.145
# ==============================================================================
# """

# %%
result.llf
# Out:
# -235.38625076986077

# %%
result.df_model
# Out:
# 1

# %%
x = np.linspace(7, 13, 100)
y = np.exp(result.params["Intercept"] + x*result.params["x"])

plt.scatter(data.x, data.y, c=data.f)
plt.plot(x, y, "r--")
plt.show()

# %%
x = np.linspace(7, 13, 100)

plt.scatter(data.x, data.y, c=data.f)
plt.plot(x, result.predict({"x":x}), "r--")
plt.show()

# %%
model = smf.glm('y ~ f', data = data, family = sm.families.Poisson())
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  100
# Model:                            GLM   Df Residuals:                       98
# Model Family:                 Poisson   Df Model:                            1
# Link Function:                    log   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -237.63
# Date:                Sun, 18 Mar 2018   Deviance:                       89.475
# Time:                        12:39:05   Pearson chi2:                     87.1
# No. Iterations:                     4
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.0516      0.051     40.463      0.000       1.952       2.151
# f[T.1]         0.0128      0.071      0.179      0.858      -0.127       0.153
# ==============================================================================
# """

# %%
result.llf
# Out:
# -237.62725696068685

# %%
data.head()
# Out:
#     y      x  f
# 0   6   8.31  0
# 1   6   9.44  0
# 2   6   9.50  0
# 3  12   9.07  0
# 4  10  10.16  0

# %%
model = smf.glm('y ~ x + f', data = data, family = sm.families.Poisson())
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  100
# Model:                            GLM   Df Residuals:                       97
# Model Family:                 Poisson   Df Model:                            2
# Link Function:                    log   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -235.29
# Date:                Sun, 18 Mar 2018   Deviance:                       84.808
# Time:                        12:43:38   Pearson chi2:                     83.8
# No. Iterations:                     4
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.2631      0.370      3.417      0.001       0.539       1.988
# f[T.1]        -0.0320      0.074     -0.430      0.667      -0.178       0.114
# x              0.0801      0.037      2.162      0.031       0.007       0.153
# ==============================================================================
# """

# %%
result.llf
# Out:
# -235.29371924249367

# %%
result.df_model
# Out:
# 2

# %%
from sklearn.datasets import load_linnerud
linnerud = load_linnerud()

# %%
linnerud
# Out:
# {'DESCR': 'Linnerrud dataset\n=================\n\nNotes\n-----\nData Set Characteristics:\n    :Number of Instances: 20\n    :Number of Attributes: 3\n    :Missing Attribute Values: None\n\nThe Linnerud dataset constains two small dataset:\n\n- *exercise*: A list containing the following components: exercise data with\n  20 observations on 3 exercise variables: Weight, Waist and Pulse.\n\n- *physiological*: Data frame with 20 observations on 3 physiological variables:\n   Chins, Situps and Jumps.\n\nReferences\n----------\n  * Tenenhaus, M. (1998). La regression PLS: theorie et pratique. Paris: Editions Technic.\n',
#  'data': array([[   5.,  162.,   60.],
#         [   2.,  110.,   60.],
#         [  12.,  101.,  101.],
#         [  12.,  105.,   37.],
#         [  13.,  155.,   58.],
#         [   4.,  101.,   42.],
#         [   8.,  101.,   38.],
#         [   6.,  125.,   40.],
#         [  15.,  200.,   40.],
#         [  17.,  251.,  250.],
#         [  17.,  120.,   38.],
#         [  13.,  210.,  115.],
#         [  14.,  215.,  105.],
#         [   1.,   50.,   50.],
#         [   6.,   70.,   31.],
#         [  12.,  210.,  120.],
#         [   4.,   60.,   25.],
#         [  11.,  230.,   80.],
#         [  15.,  225.,   73.],
#         [   2.,  110.,   43.]]),
#  'feature_names': ['Chins', 'Situps', 'Jumps'],
#  'target': array([[ 191.,   36.,   50.],
#         [ 189.,   37.,   52.],
#         [ 193.,   38.,   58.],
#         [ 162.,   35.,   62.],
#         [ 189.,   35.,   46.],
#         [ 182.,   36.,   56.],
#         [ 211.,   38.,   56.],
#         [ 167.,   34.,   60.],
#         [ 176.,   31.,   74.],
#         [ 154.,   33.,   56.],
#         [ 169.,   34.,   50.],
#         [ 166.,   33.,   52.],
#         [ 154.,   34.,   64.],
#         [ 247.,   46.,   50.],
#         [ 193.,   36.,   46.],
#         [ 202.,   37.,   62.],
#         [ 176.,   37.,   54.],
#         [ 157.,   32.,   52.],
#         [ 156.,   33.,   54.],
#         [ 138.,   33.,   68.]]),
#  'target_names': ['Weight', 'Waist', 'Pulse']}

# %%
df_csj = pd.DataFrame(linnerud.data, columns = linnerud.feature_names)

# %%
df_csj.head()
# Out:
#    Chins  Situps  Jumps
# 0    5.0   162.0   60.0
# 1    2.0   110.0   60.0
# 2   12.0   101.0  101.0
# 3   12.0   105.0   37.0
# 4   13.0   155.0   58.0

# %%
df_wwp = pd.DataFrame(linnerud.target, columns=linnerud.target_names)

# %%
df_wwp.head()
# Out:
#    Weight  Waist  Pulse
# 0   191.0   36.0   50.0
# 1   189.0   37.0   52.0
# 2   193.0   38.0   58.0
# 3   162.0   35.0   62.0
# 4   189.0   35.0   46.0

# %%
df_wwp["Chins"] = df_csj.Chins

# %%
df_wwp.head()
# Out:
#    Weight  Waist  Pulse  Chins
# 0   191.0   36.0   50.0    5.0
# 1   189.0   37.0   52.0    2.0
# 2   193.0   38.0   58.0   12.0
# 3   162.0   35.0   62.0   12.0
# 4   189.0   35.0   46.0   13.0

# %%
model = smf.glm('Chins ~ Weight + Waist + Pulse', data = df_wwp, family = sm.families.Poisson())
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                  Chins   No. Observations:                   20
# Model:                            GLM   Df Residuals:                       16
# Model Family:                 Poisson   Df Model:                            3
# Link Function:                    log   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -60.048
# Date:                Sun, 18 Mar 2018   Deviance:                       42.548
# Time:                        12:57:59   Pearson chi2:                     39.8
# No. Iterations:                     4
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.7521      1.503      5.157      0.000       4.806      10.698
# Weight         0.0067      0.006      1.168      0.243      -0.005       0.018
# Waist         -0.1807      0.049     -3.654      0.000      -0.278      -0.084
# Pulse         -0.0068      0.010     -0.677      0.499      -0.027       0.013
# ==============================================================================
# """

# %%
df_wwp["predict"] = result.predict(df_wwp[["Weight", "Waist", "Pulse"]])
df_wwp
# Out:
#     Weight  Waist  Pulse  Chins    predict
# 0    191.0   36.0   50.0    5.0   8.946231
# 1    189.0   37.0   52.0    2.0   7.267619
# 2    193.0   38.0   58.0   12.0   5.981289
# 3    162.0   35.0   62.0   12.0   8.122894
# 4    189.0   35.0   46.0   13.0  10.867774
# 5    182.0   36.0   56.0    4.0   8.081955
# 6    211.0   38.0   56.0    8.0   6.844403
# 7    167.0   34.0   60.0    6.0  10.202940
# 8    176.0   31.0   74.0   15.0  16.936457
# 9    154.0   33.0   56.0   17.0  11.510169
# 10   169.0   34.0   50.0   17.0  11.073281
# 11   166.0   33.0   52.0   13.0  12.824211
# 12   154.0   34.0   64.0   14.0   9.096078
# 13   247.0   46.0   50.0    1.0   2.141217
# 14   193.0   36.0   46.0    6.0   9.318954
# 15   202.0   37.0   62.0   12.0   7.407542
# 16   176.0   37.0   54.0    4.0   6.568441
# 17   157.0   32.0   52.0   11.0  14.460827
# 18   156.0   33.0   54.0   15.0  11.826804
# 19   138.0   33.0   68.0    2.0   9.520914

# %%
plt.scatter(df_wwp.Chins, df_wwp.predict)
plt.xlabel("Chins")
plt.ylabel("Predict")
# Out:
# Text(0,0.5,'Predict')
